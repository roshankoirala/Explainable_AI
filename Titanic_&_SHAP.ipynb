# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
num_cols = ['Age', 'Fare']
cat_cols = ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']
target = 'Survived'

df = pd.read_csv('titanic.csv', 
                 usecols = num_cols+cat_cols+[target])

X = df.copy()
y = X.pop(target)

X.sample(5)
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 870       3    male  26.0      0      0    7.8958        S
# 657       3  female  32.0      1      1   15.5000        Q
# 93        3    male  26.0      1      2   20.5750        S
# 233       3  female   5.0      4      2   31.3875        S
# 557       1    male   NaN      0      0  227.5250        C

# %% [markdown]
# # Cleaning

# %%
X['Sex'] = X['Sex'].map({'male':0, 'female':1})
X['Embarked'] = X['Embarked'].map({'S':1, 'C':2, 'Q':3})

X = X.fillna(X.mode().loc[0])
X.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       3    0  22.0      1      0   7.2500       1.0
# 1       1    1  38.0      1      0  71.2833       2.0
# 2       3    1  26.0      0      0   7.9250       1.0
# 3       1    1  35.0      1      0  53.1000       1.0
# 4       3    0  35.0      0      0   8.0500       1.0

# %% [markdown]
# # Model

# %%
from lightgbm import LGBMClassifier

# %%
model = LGBMClassifier()
model.fit(X, y)
model.score(X, y)
# Out:
# 0.9472502805836139

# %% [markdown]
# # SHAP

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
explainer = shap.Explainer(model)
shap_values = explainer(X)

# %% [markdown]
# # Local Explanation

# %%
passenger_id = 100
shap.plots.bar(shap_values[passenger_id, :, 1], max_display=None)

# %%
shap.plots.waterfall(shap_values[passenger_id, :, 1])

# %%
shap.plots.force(shap_values.base_values[passenger_id][1], 
                 shap_values.values[passenger_id][:, 1], 
                 X.iloc[passenger_id], matplotlib=True)

# %% [markdown]
# # Feature Importance

# %%
shap.summary_plot(shap_values[:, :, 1], plot_type='bar', color='tab:blue')

# %%
shap.summary_plot(shap_values[:, :, 0], plot_type='violin')

# %% [markdown]
# # Partial Dependence

# %%
shap.dependence_plot(1, shap_values.values[:, :, 1], X, 
                     interaction_index=None)

# %%
for i in range(len(X.columns[:3])):
    shap.dependence_plot('rank({})'.format(i), shap_values.values[:, :, 1], X, 
                         interaction_index=None
                        )

# %% [markdown]
# # Embeding

# %%
for i in range(len(X.columns[:3])):
        shap.embedding_plot('rank({})'.format(i), shap_values.values[:, :, 0], 
                        feature_names=X.columns)
